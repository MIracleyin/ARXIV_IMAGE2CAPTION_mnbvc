# %%
import pandas as pd
import os

# %%
data = pd.read_parquet(r'../data_output\data-table-total\0_10000.parquet')

# %%
print(data['文本'].values[0])
# Out:
# None

# %%
data.head(100)
# Out:
#                          实体ID  块ID        时间                             扩展字段  \
# 0    arXiv-0704.0388v2.tar.gz    0  20241214  {"file_type": "table/equation"}
# 1    arXiv-0704.0388v2.tar.gz    1  20241214  {"file_type": "table/equation"}
# 2    arXiv-0704.0388v2.tar.gz    2  20241214  {"file_type": "table/equation"}
# 3    arXiv-0704.0388v2.tar.gz    3  20241214  {"file_type": "table/equation"}
# 4    arXiv-0704.0388v2.tar.gz    4  20241214  {"file_type": "table/equation"}
# 5    arXiv-0704.0388v2.tar.gz    5  20241214  {"file_type": "table/equation"}
# 6    arXiv-0704.0388v2.tar.gz    6  20241214  {"file_type": "table/equation"}
# 7    arXiv-0704.0388v2.tar.gz    7  20241214  {"file_type": "table/equation"}
# 8    arXiv-0704.0388v2.tar.gz    8  20241214  {"file_type": "table/equation"}
# 9    arXiv-0704.0388v2.tar.gz    9  20241214  {"file_type": "table/equation"}
# 10   arXiv-0704.0388v2.tar.gz   10  20241214  {"file_type": "table/equation"}
# ...
